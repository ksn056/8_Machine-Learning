# %%
path="/content/drive/MyDrive/Dataset/drug200.csv"

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(path)

# %%
df.head(15)
# Out:
#     Age Sex      BP Cholesterol  Na_to_K   Drug
# 0    23   F    HIGH        HIGH   25.355  drugY
# 1    47   M     LOW        HIGH   13.093  drugC
# 2    47   M     LOW        HIGH   10.114  drugC
# 3    28   F  NORMAL        HIGH    7.798  drugX
# 4    61   F     LOW        HIGH   18.043  drugY
# 5    22   F  NORMAL        HIGH    8.607  drugX
# 6    49   F  NORMAL        HIGH   16.275  drugY
# 7    41   M     LOW        HIGH   11.037  drugC
# 8    60   M  NORMAL        HIGH   15.171  drugY
# 9    43   M     LOW      NORMAL   19.368  drugY
# 10   47   F     LOW        HIGH   11.767  drugC
# 11   34   F    HIGH      NORMAL   19.199  drugY
# 12   43   M     LOW        HIGH   15.376  drugY
# 13   74   F     LOW        HIGH   20.942  drugY
# 14   50   F  NORMAL        HIGH   12.703  drugX

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'BP', 'Cholesterol', 'Na_to_K', 'Drug'], dtype='object')

# %%
df.describe()
# Out:
#               Age     Na_to_K
# count  200.000000  200.000000
# mean    44.315000   16.084485
# std     16.544315    7.223956
# min     15.000000    6.269000
# 25%     31.000000   10.445500
# 50%     45.000000   13.936500
# 75%     58.000000   19.380000
# max     74.000000   38.247000

# %%
df.dtypes
# Out:
# Age              int64
# Sex             object
# BP              object
# Cholesterol     object
# Na_to_K        float64
# Drug            object
# dtype: object

# %%
df.isnull()
# Out:
#        Age    Sex     BP  Cholesterol  Na_to_K   Drug
# 0    False  False  False        False    False  False
# 1    False  False  False        False    False  False
# 2    False  False  False        False    False  False
# 3    False  False  False        False    False  False
# 4    False  False  False        False    False  False
# ..     ...    ...    ...          ...      ...    ...
# 195  False  False  False        False    False  False
# 196  False  False  False        False    False  False
# 197  False  False  False        False    False  False
# 198  False  False  False        False    False  False
# 199  False  False  False        False    False  False
#
# [200 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na_to_K        0
# Drug           0
# dtype: int64

# %%
df['Drug']
# Out:
# 0      drugY
# 1      drugC
# 2      drugC
# 3      drugX
# 4      drugY
#        ...
# 195    drugC
# 196    drugC
# 197    drugX
# 198    drugX
# 199    drugX
# Name: Drug, Length: 200, dtype: object

# %%
df['Drug'].value_counts()
# Out:
# drugY    91
# drugX    54
# drugA    23
# drugC    16
# drugB    16
# Name: Drug, dtype: int64

# %%
df['BP']
# Out:
# 0        HIGH
# 1         LOW
# 2         LOW
# 3      NORMAL
# 4         LOW
#         ...
# 195       LOW
# 196       LOW
# 197    NORMAL
# 198    NORMAL
# 199       LOW
# Name: BP, Length: 200, dtype: object

# %%
df['BP'].value_counts()
# Out:
# HIGH      77
# LOW       64
# NORMAL    59
# Name: BP, dtype: int64

# %%
import seaborn as sns
sns.histplot(df['BP'])

# %%
import seaborn as sns
sns.histplot(df['Drug'])

# %%
df1=df

# %%
df1.head()
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  drugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  drugY

# %%
df1['Sex'].value_counts()
# Out:
# M    104
# F     96
# Name: Sex, dtype: int64

# %%
dummy_df=pd.get_dummies(df1['Sex'])

# %%
dummy_df
# Out:
#      F  M
# 0    1  0
# 1    0  1
# 2    0  1
# 3    1  0
# 4    1  0
# ..  .. ..
# 195  1  0
# 196  0  1
# 197  0  1
# 198  0  1
# 199  1  0
#
# [200 rows x 2 columns]

# %%
df1
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug
# 0     23   F    HIGH        HIGH   25.355  drugY
# 1     47   M     LOW        HIGH   13.093  drugC
# 2     47   M     LOW        HIGH   10.114  drugC
# 3     28   F  NORMAL        HIGH    7.798  drugX
# 4     61   F     LOW        HIGH   18.043  drugY
# ..   ...  ..     ...         ...      ...    ...
# 195   56   F     LOW        HIGH   11.567  drugC
# 196   16   M     LOW        HIGH   12.006  drugC
# 197   52   M  NORMAL        HIGH    9.894  drugX
# 198   23   M  NORMAL      NORMAL   14.020  drugX
# 199   40   F     LOW      NORMAL   11.349  drugX
#
# [200 rows x 6 columns]

# %%
dummy_df.rename(columns={'M':'Sex Male','F':'Sex Female'},inplace=True)

# %%
dummy_df
# Out:
#      Sex Female  Sex Male
# 0             1         0
# 1             0         1
# 2             0         1
# 3             1         0
# 4             1         0
# ..          ...       ...
# 195           1         0
# 196           0         1
# 197           0         1
# 198           0         1
# 199           1         0
#
# [200 rows x 2 columns]

# %%
df2=pd.concat([df1,dummy_df],axis=1)

# %%
df2
# Out:
#      Age Sex      BP Cholesterol  Na_to_K   Drug  Sex Female  Sex Male
# 0     23   F    HIGH        HIGH   25.355  drugY           1         0
# 1     47   M     LOW        HIGH   13.093  drugC           0         1
# 2     47   M     LOW        HIGH   10.114  drugC           0         1
# 3     28   F  NORMAL        HIGH    7.798  drugX           1         0
# 4     61   F     LOW        HIGH   18.043  drugY           1         0
# ..   ...  ..     ...         ...      ...    ...         ...       ...
# 195   56   F     LOW        HIGH   11.567  drugC           1         0
# 196   16   M     LOW        HIGH   12.006  drugC           0         1
# 197   52   M  NORMAL        HIGH    9.894  drugX           0         1
# 198   23   M  NORMAL      NORMAL   14.020  drugX           0         1
# 199   40   F     LOW      NORMAL   11.349  drugX           1         0
#
# [200 rows x 8 columns]

# %%
df_temp=df2.drop('Sex',axis=1)

# %%
df_temp.head()
# Out:
#    Age      BP Cholesterol  Na_to_K   Drug  Sex Female  Sex Male
# 0   23    HIGH        HIGH   25.355  drugY           1         0
# 1   47     LOW        HIGH   13.093  drugC           0         1
# 2   47     LOW        HIGH   10.114  drugC           0         1
# 3   28  NORMAL        HIGH    7.798  drugX           1         0
# 4   61     LOW        HIGH   18.043  drugY           1         0

# %%
dummy_df1=pd.get_dummies(df1['BP'])
dummy_df1.head()
# Out:
#    HIGH  LOW  NORMAL
# 0     1    0       0
# 1     0    1       0
# 2     0    1       0
# 3     0    0       1
# 4     0    1       0

# %%
dummy_df1.rename(columns={'HIGH':'HIGH_BP','LOW':'LOW_BP','NORMAL':'NORMAL_BP'},inplace=True)

# %%
dummy_df1.head()
# Out:
#    HIGH_BP  LOW_BP  NORMAL_BP
# 0        1       0          0
# 1        0       1          0
# 2        0       1          0
# 3        0       0          1
# 4        0       1          0

# %%
df3=pd.concat([df_temp,dummy_df1],axis=1)

# %%
df3
# Out:
#      Age      BP Cholesterol  Na_to_K   Drug  Sex Female  Sex Male  HIGH_BP  \
# 0     23    HIGH        HIGH   25.355  drugY           1         0        1
# 1     47     LOW        HIGH   13.093  drugC           0         1        0
# 2     47     LOW        HIGH   10.114  drugC           0         1        0
# 3     28  NORMAL        HIGH    7.798  drugX           1         0        0
# 4     61     LOW        HIGH   18.043  drugY           1         0        0
# ..   ...     ...         ...      ...    ...         ...       ...      ...
# 195   56     LOW        HIGH   11.567  drugC           1         0        0
# 196   16     LOW        HIGH   12.006  drugC           0         1        0
# 197   52  NORMAL        HIGH    9.894  drugX           0         1        0
# 198   23  NORMAL      NORMAL   14.020  drugX           0         1        0
# 199   40     LOW      NORMAL   11.349  drugX           1         0        0
#
#      LOW_BP  NORMAL_BP
# 0         0          0
# 1         1          0
# 2         1          0
# 3         0          1
# 4         1          0
# ..      ...        ...
# 195       1          0
# 196       1          0
# 197       0          1
# 198       0          1
# 199       1          0
#
# [200 rows x 10 columns]

# %%
df3.drop('BP',axis=1,inplace=True)

# %%
df3.head()
# Out:
#    Age Cholesterol  Na_to_K   Drug  Sex Female  Sex Male  HIGH_BP  LOW_BP  \
# 0   23        HIGH   25.355  drugY           1         0        1       0
# 1   47        HIGH   13.093  drugC           0         1        0       1
# 2   47        HIGH   10.114  drugC           0         1        0       1
# 3   28        HIGH    7.798  drugX           1         0        0       0
# 4   61        HIGH   18.043  drugY           1         0        0       1
#
#    NORMAL_BP
# 0          0
# 1          0
# 2          0
# 3          1
# 4          0

# %%
dummy_df2=pd.get_dummies(df1['Cholesterol'])
dummy_df2.head()
# Out:
#    HIGH  NORMAL
# 0     1       0
# 1     1       0
# 2     1       0
# 3     1       0
# 4     1       0

# %%
dummy_df2.rename(columns={'HIGH':'HIGH_Chlo','NORMAL':'NORMAL_Chlo'},inplace=True)

# %%
df4=pd.concat([df3,dummy_df2],axis=1)

# %%
df4
# Out:
#      Age Cholesterol  Na_to_K   Drug  Sex Female  Sex Male  HIGH_BP  LOW_BP  \
# 0     23        HIGH   25.355  drugY           1         0        1       0
# 1     47        HIGH   13.093  drugC           0         1        0       1
# 2     47        HIGH   10.114  drugC           0         1        0       1
# 3     28        HIGH    7.798  drugX           1         0        0       0
# 4     61        HIGH   18.043  drugY           1         0        0       1
# ..   ...         ...      ...    ...         ...       ...      ...     ...
# 195   56        HIGH   11.567  drugC           1         0        0       1
# 196   16        HIGH   12.006  drugC           0         1        0       1
# 197   52        HIGH    9.894  drugX           0         1        0       0
# 198   23      NORMAL   14.020  drugX           0         1        0       0
# 199   40      NORMAL   11.349  drugX           1         0        0       1
#
#      NORMAL_BP  HIGH_Chlo  NORMAL_Chlo
# 0            0          1            0
# 1            0          1            0
# 2            0          1            0
# 3            1          1            0
# 4            0          1            0
# ..         ...        ...          ...
# 195          0          1            0
# 196          0          1            0
# 197          1          1            0
# 198          1          0            1
# 199          0          0            1
#
# [200 rows x 11 columns]

# %%
df4.drop('Cholesterol',axis=1,inplace=True)

# %%
df4
# Out:
#      Age  Na_to_K   Drug  Sex Female  Sex Male  HIGH_BP  LOW_BP  NORMAL_BP  \
# 0     23   25.355  drugY           1         0        1       0          0
# 1     47   13.093  drugC           0         1        0       1          0
# 2     47   10.114  drugC           0         1        0       1          0
# 3     28    7.798  drugX           1         0        0       0          1
# 4     61   18.043  drugY           1         0        0       1          0
# ..   ...      ...    ...         ...       ...      ...     ...        ...
# 195   56   11.567  drugC           1         0        0       1          0
# 196   16   12.006  drugC           0         1        0       1          0
# 197   52    9.894  drugX           0         1        0       0          1
# 198   23   14.020  drugX           0         1        0       0          1
# 199   40   11.349  drugX           1         0        0       1          0
#
#      HIGH_Chlo  NORMAL_Chlo
# 0            1            0
# 1            1            0
# 2            1            0
# 3            1            0
# 4            1            0
# ..         ...          ...
# 195          1            0
# 196          1            0
# 197          1            0
# 198          0            1
# 199          0            1
#
# [200 rows x 10 columns]

# %%
df4.columns
# Out:
# Index(['Age', 'Na_to_K', 'Drug', 'Sex Female', 'Sex Male', 'HIGH_BP', 'LOW_BP',
#        'NORMAL_BP', 'HIGH_Chlo', 'NORMAL_Chlo'],
#       dtype='object')

# %%
X=df4[['Age', 'Na_to_K', 'Sex Female', 'Sex Male', 'HIGH_BP', 'LOW_BP',
       'NORMAL_BP', 'HIGH_Chlo', 'NORMAL_Chlo']]

# %%
Y=df4['Drug']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
#      Age  Na_to_K  Sex Female  Sex Male  HIGH_BP  LOW_BP  NORMAL_BP  \
# 31    74    9.567           0         1        1       0          0
# 67    17   10.832           0         1        0       0          1
# 169   20   11.262           1         0        1       0          0
# 44    50   12.295           1         0        0       0          1
# 36    32    9.445           0         1        1       0          0
# ..   ...      ...         ...       ...      ...     ...        ...
# 71    28   19.675           1         0        0       0          1
# 177   25   19.011           0         1        0       0          1
# 9     43   19.368           0         1        0       1          0
# 38    39    9.709           1         0        0       0          1
# 34    53   14.133           0         1        0       0          1
#
#      HIGH_Chlo  NORMAL_Chlo
# 31           1            0
# 67           0            1
# 169          1            0
# 44           0            1
# 36           0            1
# ..         ...          ...
# 71           1            0
# 177          1            0
# 9            0            1
# 38           0            1
# 34           1            0
#
# [160 rows x 9 columns]

# %%
Y_train
# Out:
# 31     drugB
# 67     drugX
# 169    drugA
# 44     drugX
# 36     drugA
#        ...
# 71     drugY
# 177    drugY
# 9      drugY
# 38     drugX
# 34     drugX
# Name: Drug, Length: 160, dtype: object

# %%
X_train.shape
# Out:
# (160, 9)

# %%
Y_train.shape
# Out:
# (160,)

# %%
X_test.shape
# Out:
# (40, 9)

# %%
Y_test.shape
# Out:
# (40,)

# %%
from sklearn import tree
clf=tree.DecisionTreeClassifier(criterion='gini',splitter='random')

# %%
model=clf.fit(X_train, Y_train)

# %%
Y_pred=model.predict(X_test)

# %%
Y_pred[0:5]
# Out:
# array(['drugY', 'drugY', 'drugX', 'drugX', 'drugY'], dtype=object)

# %%
Y_test[0:5]
# Out:
# 88     drugY
# 97     drugY
# 182    drugX
# 27     drugX
# 109    drugY
# Name: Drug, dtype: object

# %%
from sklearn import metrics

print (metrics.accuracy_score(Y_test, Y_pred))
# Out:
# 0.975

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5661764705882353, 0.9545454545454546, 'X[1] <= 19.556\ngini = 0.689\nsamples = 160\nvalue = [21, 14, 10, 40, 75]'),
#  Text(0.5367647058823529, 0.8636363636363636, 'X[4] <= 0.071\ngini = 0.752\nsamples = 121\nvalue = [21, 14, 10, 40, 36]'),
#  Text(0.23529411764705882, 0.7727272727272727, 'X[8] <= 0.343\ngini = 0.571\nsamples = 70\nvalue = [0, 0, 10, 40, 20]'),
#  Text(0.14705882352941177, 0.6818181818181818, 'X[5] <= 0.848\ngini = 0.657\nsamples = 39\nvalue = [0, 0, 10, 15, 14]'),
#  Text(0.058823529411764705, 0.5909090909090909, 'X[1] <= 12.284\ngini = 0.434\nsamples = 22\nvalue = [0, 0, 0, 15, 7]'),
#  Text(0.029411764705882353, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0]'),
#  Text(0.08823529411764706, 0.5, 'X[1] <= 13.613\ngini = 0.463\nsamples = 11\nvalue = [0, 0, 0, 4, 7]'),
#  Text(0.058823529411764705, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.11764705882352941, 0.4090909090909091, 'X[0] <= 58.603\ngini = 0.346\nsamples = 9\nvalue = [0, 0, 0, 2, 7]'),
#  Text(0.08823529411764706, 0.3181818181818182, 'X[0] <= 34.013\ngini = 0.444\nsamples = 6\nvalue = [0, 0, 0, 2, 4]'),
#  Text(0.058823529411764705, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.11764705882352941, 0.22727272727272727, 'X[1] <= 14.791\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 2, 3]'),
#  Text(0.08823529411764706, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0]'),
#  Text(0.14705882352941177, 0.13636363636363635, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.14705882352941177, 0.3181818181818182, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.23529411764705882, 0.5909090909090909, 'X[1] <= 18.023\ngini = 0.484\nsamples = 17\nvalue = [0, 0, 10, 0, 7]'),
#  Text(0.20588235294117646, 0.5, 'X[1] <= 10.018\ngini = 0.469\nsamples = 16\nvalue = [0, 0, 10, 0, 6]'),
#  Text(0.17647058823529413, 0.4090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.23529411764705882, 0.4090909090909091, 'X[1] <= 12.665\ngini = 0.49\nsamples = 14\nvalue = [0, 0, 8, 0, 6]'),
#  Text(0.20588235294117646, 0.3181818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 5, 0, 0]'),
#  Text(0.2647058823529412, 0.3181818181818182, 'X[1] <= 15.222\ngini = 0.444\nsamples = 9\nvalue = [0, 0, 3, 0, 6]'),
#  Text(0.23529411764705882, 0.22727272727272727, 'X[1] <= 13.819\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 3, 0, 2]'),
#  Text(0.20588235294117646, 0.13636363636363635, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0]'),
#  Text(0.2647058823529412, 0.13636363636363635, 'X[1] <= 14.283\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2]'),
#  Text(0.23529411764705882, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0]'),
#  Text(0.29411764705882354, 0.045454545454545456, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.29411764705882354, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.2647058823529412, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.3235294117647059, 0.6818181818181818, 'X[1] <= 8.656\ngini = 0.312\nsamples = 31\nvalue = [0, 0, 0, 25, 6]'),
#  Text(0.29411764705882354, 0.5909090909090909, 'gini = 0.0\nsamples = 6\nvalue = [0, 0, 0, 6, 0]'),
#  Text(0.35294117647058826, 0.5909090909090909, 'X[1] <= 10.068\ngini = 0.365\nsamples = 25\nvalue = [0, 0, 0, 19, 6]'),
#  Text(0.3235294117647059, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [0, 0, 0, 7, 0]'),
#  Text(0.38235294117647056, 0.5, 'X[1] <= 18.478\ngini = 0.444\nsamples = 18\nvalue = [0, 0, 0, 12, 6]'),
#  Text(0.35294117647058826, 0.4090909090909091, 'X[1] <= 14.158\ngini = 0.32\nsamples = 15\nvalue = [0, 0, 0, 12, 3]'),
#  Text(0.3235294117647059, 0.3181818181818182, 'gini = 0.0\nsamples = 11\nvalue = [0, 0, 0, 11, 0]'),
#  Text(0.38235294117647056, 0.3181818181818182, 'X[0] <= 57.259\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 3]'),
#  Text(0.35294117647058826, 0.22727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.4117647058823529, 0.22727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0]'),
#  Text(0.4117647058823529, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3]'),
#  Text(0.8382352941176471, 0.7727272727272727, 'X[0] <= 71.348\ngini = 0.657\nsamples = 51\nvalue = [21, 14, 0, 0, 16]'),
#  Text(0.7352941176470589, 0.6818181818181818, 'X[1] <= 13.784\ngini = 0.646\nsamples = 47\nvalue = [21, 12, 0, 0, 14]'),
#  Text(0.6176470588235294, 0.5909090909090909, 'X[0] <= 61.702\ngini = 0.428\nsamples = 29\nvalue = [20, 9, 0, 0, 0]'),
#  Text(0.5882352941176471, 0.5, 'X[2] <= 0.768\ngini = 0.355\nsamples = 26\nvalue = [20, 6, 0, 0, 0]'),
#  Text(0.5294117647058824, 0.4090909090909091, 'X[7] <= 0.063\ngini = 0.245\nsamples = 14\nvalue = [12, 2, 0, 0, 0]'),
#  Text(0.5, 0.3181818181818182, 'X[0] <= 35.278\ngini = 0.32\nsamples = 10\nvalue = [8, 2, 0, 0, 0]'),
#  Text(0.47058823529411764, 0.22727272727272727, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]'),
#  Text(0.5294117647058824, 0.22727272727272727, 'X[0] <= 57.094\ngini = 0.444\nsamples = 6\nvalue = [4, 2, 0, 0, 0]'),
#  Text(0.5, 0.13636363636363635, 'X[0] <= 49.353\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0, 0, 0]'),
#  Text(0.47058823529411764, 0.045454545454545456, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]'),
#  Text(0.5294117647058824, 0.045454545454545456, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.5588235294117647, 0.13636363636363635, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.5588235294117647, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0]'),
#  Text(0.6470588235294118, 0.4090909090909091, 'X[0] <= 46.328\ngini = 0.444\nsamples = 12\nvalue = [8, 4, 0, 0, 0]'),
#  Text(0.6176470588235294, 0.3181818181818182, 'gini = 0.0\nsamples = 8\nvalue = [8, 0, 0, 0, 0]'),
#  Text(0.6764705882352942, 0.3181818181818182, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0]'),
#  Text(0.6470588235294118, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.8529411764705882, 0.5909090909090909, 'X[0] <= 47.439\ngini = 0.364\nsamples = 18\nvalue = [1, 3, 0, 0, 14]'),
#  Text(0.7941176470588235, 0.5, 'X[8] <= 0.526\ngini = 0.165\nsamples = 11\nvalue = [1, 0, 0, 0, 10]'),
#  Text(0.7647058823529411, 0.4090909090909091, 'X[1] <= 16.08\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1]'),
#  Text(0.7352941176470589, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0]'),
#  Text(0.7941176470588235, 0.3181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1]'),
#  Text(0.8235294117647058, 0.4090909090909091, 'gini = 0.0\nsamples = 9\nvalue = [0, 0, 0, 0, 9]'),
#  Text(0.9117647058823529, 0.5, 'X[1] <= 14.284\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 0, 0, 4]'),
#  Text(0.8823529411764706, 0.4090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0]'),
#  Text(0.9411764705882353, 0.4090909090909091, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 0, 0, 4]'),
#  Text(0.9411764705882353, 0.6818181818181818, 'X[1] <= 14.677\ngini = 0.5\nsamples = 4\nvalue = [0, 2, 0, 0, 2]'),
#  Text(0.9117647058823529, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0]'),
#  Text(0.9705882352941176, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2]'),
#  Text(0.5955882352941176, 0.8636363636363636, 'gini = 0.0\nsamples = 39\nvalue = [0, 0, 0, 0, 39]')]
